# %% [markdown]
# <a href="https://colab.research.google.com/github/Kitan-Dara06/CNN-image-recogniser/blob/main/CNN_image_recogniser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

from keras.models import Sequential

# %%
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
classifier = Sequential()
classifier.add(Conv2D(32,(3,3), input_shape = (64,64,3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier.add(Flatten())


classifier.add(Dense(units= 128, activation= 'relu'))
classifier.add(Dense(units= 1, activation= 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range= 0.2, horizontal_flip= True)

# %%
training_set = train_datagen.flow_from_directory('dataset/training_set', target_size = (64,64), batch_size = 32, class_mode = 'binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-e37e2a2a7915> in <cell line: 0>()
# ----> 1 training_set = train_datagen.flow_from_directory('dataset/training_set', target_size = (64,64), batch_size = 32, class_mode = 'binary')
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
classifier.fit_generator(training_set,
                         steps_per_epoch = 8000,
                         epoch,)

# %%
from tensorflow.keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
model = Sequential([
    Conv2D(10, 3, activation = 'relu', input_shape = (32,32,3)),
    Conv2D(10, 3, activation ='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(1, activation= 'sigmoid')

])

# %%
model.compile(loss= 'binary_crossentropy', metrics =['accuracy'], optimizer= 'Adam')

# %%
model.fit(x_train, y_train)

# %%
model.evaluate(x_test, y_test)

# %%
import matplotlib.pyplot as plt

# %%
import random
plt.figure(figsize = (7,7))
for i in range(49):
    plt.subplot(7,7,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)

# %%
import numpy as np

np.unique(y_train)

# %%
model = Sequential([
    Conv2D(10, 3, activation = 'relu', input_shape = (32,32,3)),

    Conv2D(10, 3, activation ='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(10, activation= 'softmax')

])

# %%
model.compile(loss= 'sparse_categorical_crossentropy', metrics =['accuracy'], optimizer= 'Adam')

# %%
model.fit(x_train, y_train)

# %%
model.evaluate(x_test, y_test)

# %%
model = Sequential([
    Conv2D(10, 3, activation = 'relu', input_shape = (32,32,3)),

    Conv2D(10, 3, activation ='relu'),
    # MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(10, activation= 'softmax')

])

model.compile(loss= 'sparse_categorical_crossentropy', metrics =['accuracy'], optimizer= 'Adam')

# %%
model.fit(x_train, y_train)

# %%
model.evaluate(x_test, y_test)

# %%
model = Sequential([
    Conv2D(10, 3, activation = 'relu', input_shape = (32,32,3)),
    Conv2D(10, 3, activation ='relu'),
    Conv2D(10, 3, activation ='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(10, activation= 'softmax')

])

model.compile(loss= 'sparse_categorical_crossentropy', metrics =['accuracy'], optimizer= 'Adam')

# %%
model.fit(x_train, y_train)

# %%
model = Sequential([
    Conv2D(32, 3, activation = 'relu', input_shape = (32,32,3)),
    Conv2D(32, 3, activation ='relu'),
    Conv2D(32, 3, activation ='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(10, activation= 'softmax')

])

model.compile(loss= 'sparse_categorical_crossentropy', metrics =['accuracy'], optimizer= 'Adam')

# %%
model.fit(x_train, y_train)

# %%
model.evaluate(x_test, y_test)

# %%
model = Sequential([
    Conv2D(32, 3, activation = 'relu', input_shape = (32,32,3)),
    Conv2D(32, 3, activation ='relu'),
    Conv2D(32, 3, activation ='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation= 'softmax')

])

model.compile(loss= 'sparse_categorical_crossentropy', metrics =['accuracy'], optimizer= 'Adam')

# %%
model.fit(x_train, y_train, epochs=5)

# %%
model.evaluate(x_test, y_test)

# %%
model.fit(x_train, y_train, epochs=10)

# %%
model.evaluate(x_test, y_test)

# %%
model = Sequential([
    Conv2D(32, 3, activation = 'relu', input_shape = (32,32,3)),
    Conv2D(32, 3, activation ='relu'),
    MaxPooling2D(pool_size=(2)),
    Conv2D(32, 3, activation ='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation= 'softmax')

])

from tensorflow.keras.optimizers import Adam

optimizer = Adam()


model.compile(loss= 'sparse_categorical_crossentropy', metrics =['accuracy'], optimizer= optimizer)

# %%
model.fit(x_train, y_train, epochs = 10)
# Out:
# Epoch 1/10
#   27/1563 ━━━━━━━━━━━━━━━━━━━━ 1:36 63ms/step - accuracy: 0.1293 - loss: 30.7121
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-1859f4f5effc> in <cell line: 0>()
# ----> 1 model.fit(x_train, y_train, epochs = 10)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.6746 - loss: 1.2385
# [1.2649208307266235, 0.6751000285148621]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.2),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.3),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.4),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# x_train_augument1 = ImageDataGenerator(rescale=1./255,
#                                       shear_range = 0.2,
#                                       rotation_range = 20,
#                                       width_shift_range=0.1,
#                                       height_shift_range=0.1,
#                                       zoom_range=0.2,

#     horizontal_flip=True,
#     fill_mode='nearest'
#                                       )

# x_train_augument = ImageDataGenerator(rescale=1./255,
#     rotation_range=10,
#     width_shift_range=0.05,
#     height_shift_range=0.05,
#     zoom_range=0.1,
#     horizontal_flip=True)


x_train_augument = ImageDataGenerator(rescale=1./255,
    rotation_range=10,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.05,
    height_shift_range=0.05,

    zoom_range=0.05,
    horizontal_flip=True)

x_train_augument2 = ImageDataGenerator(rescale=1./255,
    rotation_range=20,           # Increase rotation range
    brightness_range=[0.7, 1.3], # Adjust brightness range more
    width_shift_range=0.1,       # Increase width shift
    height_shift_range=0.1,      # Increase height shift
    zoom_range=0.1,              # Increase zoom range
    horizontal_flip=True)

# %%
x_train_augument.fit(x_train)

x_train_generator = x_train_augument.flow(x_train, y_train, batch_size = 32)

x_train_generator2 = x_train_augument2.flow(x_train, y_train, batch_size = 32)
x_train_augument2.fit(x_train)

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels
images, labels = next(x_train_generator)  # Grabs the next batch

# Plot the first 9 images
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i])
    plt.title(f"Label: {int(labels[i])}")
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-60db5ab90a71>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(f"Label: {int(labels[i])}")

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

# Convert arrays into augmented batches
# train_generator = train_datagen.flow(x_train, y_train, batch_size=32)
val_generator = val_datagen.flow(x_test, y_test, batch_size=32)

# %%
model.fit(x_train_generator2, epochs = 10,validation_data=val_generator)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   51/1563 ━━━━━━━━━━━━━━━━━━━━ 2:21 94ms/step - accuracy: 0.6567 - loss: 0.9686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-dc0fd45c8d4a> in <cell line: 0>()
# ----> 1 model.fit(x_train_generator2, epochs = 10,validation_data=val_generator)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
# ...

# %%
model.fit(x_train_generator, epochs = 10,validation_data=val_generator)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 151s 96ms/step - accuracy: 0.6736 - loss: 0.9364 - val_accuracy: 0.6722 - val_loss: 0.9536
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 152s 97ms/step - accuracy: 0.6864 - loss: 0.8965 - val_accuracy: 0.6837 - val_loss: 0.9297
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 151s 97ms/step - accuracy: 0.7003 - loss: 0.8511 - val_accuracy: 0.6936 - val_loss: 0.8789
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 156s 100ms/step - accuracy: 0.7106 - loss: 0.8226 - val_accuracy: 0.7060 - val_loss: 0.8596
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 152s 97ms/step - accuracy: 0.7162 - loss: 0.8164 - val_accuracy: 0.7017 - val_loss: 0.8700
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 201s 97ms/step - accuracy: 0.7213 - loss: 0.7963 - val_accuracy: 0.7124 - val_loss: 0.8386
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 203s 98ms/step - accuracy: 0.7237 - loss: 0.7855 - val_accuracy: 0.7303 - val_loss: 0.7955
# Epoch 8/10
# ...

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# Save the best model based on val_accuracy
checkpoint = ModelCheckpoint(
    filepath='best_model.weights.h5',  # You can change the path/filename
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Stop training if val_accuracy doesn't improve after 3 epochs
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=3,  # You can tune this (e.g., 2–5 is typical)
    restore_best_weights=True,
    mode='max',
    verbose=1
)

# %%
history2 = model.fit(x_train_generator2,  callbacks=[checkpoint, early_stop], epochs = 10,validation_data=val_generator)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.2615 - loss: 2.2091
# Epoch 1: val_accuracy improved from -inf to 0.39520, saving model to best_model.weights.h5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 186s 115ms/step - accuracy: 0.2615 - loss: 2.2089 - val_accuracy: 0.3952 - val_loss: 1.8639
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.4030 - loss: 1.6368
# Epoch 2: val_accuracy improved from 0.39520 to 0.51400, saving model to best_model.weights.h5
# ...

# %%
history = model.fit(x_train_generator,  callbacks=[checkpoint, early_stop], epochs = 10,validation_data=val_generator)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5968 - loss: 1.1395
# Epoch 1: val_accuracy did not improve from 0.67160
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 188s 120ms/step - accuracy: 0.5968 - loss: 1.1395 - val_accuracy: 0.6064 - val_loss: 1.1852
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6115 - loss: 1.1083
# Epoch 2: val_accuracy did not improve from 0.67160
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 202s 120ms/step - accuracy: 0.6115 - loss: 1.1083 - val_accuracy: 0.6314 - val_loss: 1.0576
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6243 - loss: 1.0808
# Epoch 3: val_accuracy did not improve from 0.67160
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 181s 116ms/step - accuracy: 0.6243 - loss: 1.0808 - val_accuracy: 0.5352 - val_loss: 1.3563
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6370 - loss: 1.0432
# Epoch 4: val_accuracy did not improve from 0.67160
# ...

# %%
history = model.fit(x_train_generator,  callbacks=[checkpoint, early_stop], epochs = 10,validation_data=val_generator)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3620 - loss: 1.7331
# Epoch 1: val_accuracy improved from -inf to 0.54740, saving model to best_model.weights.h5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 152s 96ms/step - accuracy: 0.3620 - loss: 1.7330 - val_accuracy: 0.5474 - val_loss: 1.2786
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5838 - loss: 1.1824
# Epoch 2: val_accuracy improved from 0.54740 to 0.63860, saving model to best_model.weights.h5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 196s 92ms/step - accuracy: 0.5838 - loss: 1.1824 - val_accuracy: 0.6386 - val_loss: 1.0278
# ...

# %%
model.load_weights('best_model.weights.h5')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c56098c-aa66-4d61-90f5-1b2706221f49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c56098c-aa66-4d61-90f5-1b2706221f49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load and preprocess a single image
img = image.load_img('images.jpeg', target_size=(32, 32))  # Adjust size to match your model input
img_array = image.img_to_array(img)
img_array = img_array / 255.0  # Normalize same as training
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction, axis=1)

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']  # CIFAR-10 labels

print("Predicted label:", class_names[predicted_class[0]])

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-418fb435-5e66-4817-acd4-23bec643f907" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-418fb435-5e66-4817-acd4-23bec643f907">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-89419ca5-9c32-4e6b-800a-a73732fc23c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89419ca5-9c32-4e6b-800a-a73732fc23c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = np.load('cifar10.1_v6_data.npy')
labels = np.load('cifar10.1_v6_labels.npy')
data = data.astype("float32") / 255.0

# %%
labels
# Out:
# array([0, 0, 0, ..., 9, 9, 9], dtype=int32)

# %%
import numpy as np


label_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer',
    'dog', 'frog', 'horse', 'ship', 'truck'
]


mapped_class_names = [label_names[i] for i in labels]

print(mapped_class_names[:10])  # print the first 10 mapped names
# Out:
# ['airplane', 'airplane', 'airplane', 'airplane', 'airplane', 'airplane', 'airplane', 'airplane', 'airplane', 'airplane']

# %%
labels
# Out:
# array([0, 0, 0, ..., 9, 9, 9], dtype=int32)

# %%
predictions = model.predict(data)
predicted_classes = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(labels, predicted_classes)
print("Accuracy:", accuracy)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(labels, predicted_classes, target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.60      0.60      0.60       200
#   automobile       0.69      0.66      0.67       200
#         bird       0.48      0.55      0.51       200
#          cat       0.41      0.35      0.38       200
#         deer       0.59      0.58      0.58       200
#          dog       0.64      0.52      0.57       200
#         frog       0.66      0.62      0.64       200
#        horse       0.64      0.71      0.67       200
#         ship       0.73      0.72      0.72       200
#        truck       0.65      0.77      0.70       200
#
#     accuracy                           0.61      2000
#    macro avg       0.61      0.61      0.61      2000
# weighted avg       0.61      0.61      0.61      2000

# %%
y_true = np.argmax(labels)

# %%
misclassified_idx = np.where(predicted_classes != y_true )[0]

# %%
num_misclassified = len(misclassified_idx)
num_images_to_show = min(num_misclassified, 10)  # Show only the first 10 misclassified images

plt.figure(figsize=(15, 15))
for i in range(num_images_to_show):
    idx = misclassified_idx[i]

    # Get the true and predicted labels for the current image
    true_label = y_test[idx][0]  # Access the true label from y_test
    predicted_label = predicted_classes[idx]  # Access the predicted label

    # Plot the misclassified image
    plt.subplot(4, 4, i+1)
    plt.imshow(x_test[idx])  # Display the image
    plt.title(f"actual item: {class_names[true_label]}\nModel Pred: {class_names[predicted_label]}")
    plt.axis('off')  # Hide axis

plt.show()

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-a2334b25-0a2e-40b3-964f-8fee9b983120" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2334b25-0a2e-40b3-964f-8fee9b983120">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load and preprocess a single image
img = image.load_img('images (1).jpeg', target_size=(32, 32))  # Adjust size to match your model input
img_array = image.img_to_array(img)
img_array = img_array / 255.0  # Normalize same as training
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction, axis=1)

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']  # CIFAR-10 labels

print("Predicted label:", class_names[predicted_class[0]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predicted label: frog
